# %%
#HotelManagementProgramAashishChaudhary
import os
import datetime
rooms = []
allocations = {}

def add_room():
    try:
        room_num = input('enter room number to add: ')
        room_char = input('enter room characteristics: ')
        rooms.append({'number': room_num, 'characteristics': room_char})
        print(f"Room {room_num} added successfully.")
    except (SyntaxError, ValueError, TypeError) as e:
        print(f"Error: {e}")

def delete_room():
    try:
        room_num = input('enter a room number to delete: ')
        for room in rooms:
            if room['number'] == room_num:
                rooms.remove(room)
                print(f"Room {room_num} deleted successfully.")
                return
        print("Room not found.")
    except (SyntaxError, ValueError, TypeError) as e:
        print(f"Error: {e}")

def display_room_details():
    try:
        room_num = input('enter any room number to display its details: ')
        for room in rooms:
            if room['number'] == room_num:
                print(f"Room {room_num} details: {room['characteristics']}")
                return
        print("Room not found.")
    except (SyntaxError, ValueError, TypeError) as e:
        print(f"Error: {e}")

def room_allocation():
    try:
        room_num = input('enter a room number to allocate: ')
        customer_name = input('enter the customers name: ')
        if room_num in allocations:
            print(f"Room {room_num} is already allocated.")
        else:
            allocations[room_num] = customer_name
            print(f"Room {room_num} allocated to {customer_name}.")
    except (SyntaxError, ValueError, TypeError) as e:
        print(f"Error: {e}")


def display_room_allocation_details():
    try:
        for room_num, customer_name in allocations.items():
            print(f"Room {room_num} is allocated to {customer_name}")
    except (SyntaxError, ValueError, TypeError) as e:
        print(f"Error: {e}")

def billing_and_deallocation():
    try:
        room_num = input('enter the room number to deallocate: ')
        if room_num in allocations:
            customer_name = allocations.pop(room_num)
            print(f"Billing for {customer_name} for room {room_num}.")
            print(f"Room {room_num} deallocated.")
        else:
            print('the room has not been allocated')
    except (SyntaxError, ValueError, TypeError) as e:
        print(f"Error: {e}")

def save_allocation_to_file():
    try:
        with open("LHMS_Studentid850000796.txt", "w") as file:
            for room_num, customer_name in allocations.items():
                file.write(f"Room {room_num} allocated to {customer_name}\n")
        print("Room allocations saved to file.")
    except (IOError, FileNotFoundError) as e:
        print(f"Error: {e}")

def show_allocation_from_file():
    try:
        if os.path.exists("LHMS_Studentid850000796.txt"):
            with open("LHMS_Studentid850000796.txt", "r") as file:
                content = file.read()
                print("Room Allocations from file:")
                print(content)
        else:
            print("File not found.")
    except (IOError, FileNotFoundError) as e:
        print(f"Error: {e}")

def backup_allocation_file():
    try:
        if os.path.exists("LHMS_Studentid850000796.txt"):
            backup_filename = f"LHMS_Studentid_Backup_{datetime.datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"
            with open("LHMS_Studentid850000796.txt", "r") as original, open(backup_filename, "w") as backup:
                content = original.read()
                backup.write(content)
            os.remove("LHMS_Studentid850000796.txt")
            print(f"Backup created: {backup_filename}")
        else:
            print("File not found.")
    except (IOError, FileNotFoundError) as e:
        print(f"Error: {e}")

def main():
    while True:
        try:
            print("\nHotel Management System")
            print("1. Add Room")
            print("2. Delete Room")
            print("3. Display Room Details")
            print("4. Allocate Rooms")
            print("5. Display Room Allocation Details")
            print("6. Billing and De-allocation")
            print("7. Save Room Allocation to File")
            print("8. Show Room Allocation from File")
            print("9. Backup Room Allocation File")
            print("0. Exit Application")
            choice = input("Enter your choice: ")


            if choice == '1':
                add_room()
            elif choice == '2':
                delete_room()
            elif choice == '3':
                display_room_details()
            elif choice == '4':
                room_allocation()
            elif choice == '5':
                display_room_allocation_details()
            elif choice == '6':
                billing_and_deallocation()
            elif choice == '7':
                save_allocation_to_file()
            elif choice == '8':
                show_allocation_from_file()
            elif choice == '9':
                backup_allocation_file()
            elif choice == '0':
                print("Exiting application.")
                break
            else:
                print("Invalid choice, please try again.")
        except (SyntaxError, ValueError, IndexError, NameError, TypeError, OverflowError, EOFError, ImportError) as e:
            print(f"Error: {e}")

if __name__ == "__main__":
    main()
# Out:
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 1
# enter room number to add: 1
# enter room characteristics: 1 double bed
# Room 1 added successfully.
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 1
# enter room number to add: 2
# enter room characteristics: 2 beds
# Room 2 added successfully.
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 3
# enter any room number to display its details: 2
# Room 2 details: 2 beds
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 4
# enter a room number to allocate: 1
# enter the customers name: Aashish Chaudhary
# Room 1 allocated to Aashish Chaudhary.
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 2
# enter a room number to delete: 2
# Room 2 deleted successfully.
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 5
# Room 1 is allocated to Aashish Chaudhary
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 6
# enter the room number to deallocate: 1
# Billing for Aashish Chaudhary for room 1.
# Room 1 deallocated.
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 7
# Room allocations saved to file.
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 8
# Room Allocations from file:
#
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 9
# Backup created: LHMS_Studentid_Backup_20241128_101756.txt
#
# Hotel Management System
# 1. Add Room
# 2. Delete Room
# 3. Display Room Details
# 4. Allocate Rooms
# 5. Display Room Allocation Details
# 6. Billing and De-allocation
# 7. Save Room Allocation to File
# 8. Show Room Allocation from File
# 9. Backup Room Allocation File
# 0. Exit Application
# Enter your choice: 0
# Exiting application.
